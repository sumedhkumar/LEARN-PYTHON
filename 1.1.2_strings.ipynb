# %% [markdown]
# ## Data Types

# %%
# String = str
# Interger = int (23, 35, -2, 3, -1) Any whole number (Positive or negative)
# Float = float (12.534, -232.00) Any number with a decimal (Positive or negative)
# Boolean = bool (True / False) 
# List = list [284, 23, "fds", 214]
# Dictionary = dict/Dict {"value": "2134"}
# Tuple = tuple (1248, 235, "afd")
# Binary (0 / 1)

# %% [markdown]
# ## STRING

# %%
# String is a collection of characters that we give in single, double, or triple inverted commas.

# %%
'''8989jkasfjk'''
# Out:
# '8989jkasfjk'

# %%
"""jkajfjkhfh"""
# Out:
# 'jkajfjkhfh'

# %%
'python is very easy'
# Out:
# 'python is very easy'

# %%
"Python is easy"
# Out:
# 'Python is easy'

# %%
python = "this coding language is quite easy"
python
# Out:
# 'this coding language is quite easy'

# %%
type(python)
# Out:
# str

# %%
type("Python is easy")
# Out:
# str

# %%
type('''8989jkasfjk''')
# Out:
# str

# %%
type(4000)
# Out:
# int

# %%
type(90.01)
# Out:
# float

# %%
"3 hours ago — Catch up with the latest and breaking Cricket News, detailed analysis on trending cricket topics, series and match previews, reviews, player interviews on ..."
# Out:
# '3 hours ago — Catch up with the latest and breaking Cricket News, detailed analysis on trending cricket topics, series and match previews, reviews, player interviews on ...'

# %%
"""
What are the top 5 sports news of today cricket?
Visual Stories
Fastest Indians to 8 ODI centuries ft. ...
Champions Trophy: Virat Kohli sets new fielding record.
Mohammed Shami overtakes Bumrah, Zaheer elite ICC feat.
WPL 2025: RCB get grand welcome in Bengaluru.
Virat Kohli eyes history against Bangladesh.
Babar Azam's slowest 50s in ODIs.
"""
# Out:
# "\nWhat are the top 5 sports news of today cricket?\nVisual Stories\nFastest Indians to 8 ODI centuries ft. ...\nChampions Trophy: Virat Kohli sets new fielding record.\nMohammed Shami overtakes Bumrah, Zaheer elite ICC feat.\nWPL 2025: RCB get grand welcome in Bengaluru.\nVirat Kohli eyes history against Bangladesh.\nBabar Azam's slowest 50s in ODIs.\n"

# %%
3 hours ago — Catch up with the latest and breaking Cricket News, detailed analysis on trending cricket topics, series and match previews, reviews, player interviews on ...
# Out:
#   Cell In[12], line 1
#     3 hours ago — Catch up with the latest and breaking Cricket News, detailed analysis on trending cricket topics, series and match previews, reviews, player interviews on ...
#                 ^
# SyntaxError: invalid character '—' (U+2014)

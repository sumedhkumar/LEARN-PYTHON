# %% [markdown]
# ### Loops in python

# %%
# 1. For Loop
# 2. While Loop

# Same funcitonality but differrent syntax
# Function: It is to execute the set of statements multiple times

# %% [markdown]
# - For loop

# %%
# It works like an iterator (it iterates)
string = "I will practice python"
list1 = [1, 2, 4, 5, 6]

# Iterators > String, List, Tuple, Set, Dict, Range etc (data types)

# Syntax of for loop: 
data_type = "I will practice python"
for variable_name in data_type: 
    print(variable_name)
    statement 1 
    statement 2

# %%
string = "I write code daily"

print(string)
print(string)
print(string)
print(string)
print(string)
# Out:
# I write code daily
# I write code daily
# I write code daily
# I write code daily
# I write code daily

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
string = "I write code daily"

for i in range(5):
    print(string)
# Out:
# I write code daily
# I write code daily
# I write code daily
# I write code daily
# I write code daily

# %%
list(range(5, 10))
# Out:
# [5, 6, 7, 8, 9]

# %%
string = "I write code daily"

for i in range(5, 10):
    print(string)
# Out:
# I write code daily
# I write code daily
# I write code daily
# I write code daily
# I write code daily

# %%
string = [1, 2, 3]

for i in range(2):
    print(string)
# Out:
# [1, 2, 3]
# [1, 2, 3]

# %% [markdown]
# - for loop on string

# %%
str1 = "I am good at coding" #len(string)
print(len(str1))

for i in str1:
    print("India")
# Out:
# 19
# India
# India
# India
# India
# India
# India
# India
# India
# India
# India
# India
# India
# India
# India
# India
# India
# India
# India
# India

# %%
str1 = "I am good at coding" #len(string)
print(len(str1))

for i in str1:
    print(i, ord(i))
# Out:
# 19
# I 73
#   32
# a 97
# m 109
#   32
# g 103
# o 111
# o 111
# d 100
#   32
# a 97
# t 116
#   32
# c 99
# o 111
# d 100
# i 105
# n 110
# g 103

# %%
str2 = "I am learning loops"

for charecter in str2:
    print("charecter is: ", charecter)
    print("India won the match")
# Out:
# charecter is:  I
# India won the match
# charecter is:
# India won the match
# charecter is:  a
# India won the match
# charecter is:  m
# India won the match
# charecter is:
# India won the match
# charecter is:  l
# India won the match
# charecter is:  e
# India won the match
# charecter is:  a
# India won the match
# charecter is:  r
# India won the match
# charecter is:  n
# India won the match
# charecter is:  i
# India won the match
# charecter is:  n
# India won the match
# charecter is:  g
# India won the match
# charecter is:
# India won the match
# charecter is:  l
# India won the match
# charecter is:  o
# India won the match
# charecter is:  o
# India won the match
# charecter is:  p
# India won the match
# charecter is:  s
# India won the match

# %% [markdown]
# - loops on List

# %%
list1 = [2, 4, 5, 6, 6, 7, 9]

for i in list1:
    print(i)
# Out:
# 2
# 4
# 5
# 6
# 6
# 7
# 9

# %%
biscuit = 0

# %%
biscuit = biscuit + 1   # Increment by 1 

biscuit
# Out:
# 5

# %%
list2 = [2, 5, 6, 8, 1, 0, 1, 3]

loop_num = 0

for item in list2:
    print("loop num in list is:-->", loop_num)
    loop_num = loop_num + 1
    print(item)
loop_num
# Out:
# 8

# %%
list3 = [55, 44, 33, 11, 77]
# write a code here: 
for i in list3:
    print(i)
# Output = 
# 55
# 44
# 33
# 11
# 77
# Out:
# 55
# 44
# 33
# 11
# 77

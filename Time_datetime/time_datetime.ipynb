# %% [markdown]
# # Time & Datetime

# %% [markdown]
# ### Time.time()
# - It shows thetime that was passed since 1970
#
# - time.time()

# %%
import time
import datetime

# %%
# class time():

#   def time(self):
#     dummy code
#     start = 1970

  # def strptime(self):
  #   sfnlanf
# time = time()
# time.time()

# %%
time.time()
# Out:
# 1747060945.2287266

# %%
start_time = time.time()
print(start_time) #1pm

for i in range(100000000):
  pass

end_time = time.time()
print(end_time) # 2 pm

total_time = end_time - start_time
total_time
# Out:
# 1747061074.4061818
# 1747061078.9434543
# 4.5372724533081055

# %%
list(range(1000000000))

# %%
start_time = time.time()
print("Start time is ", start_time)


for i in range(100000000):
  pass

end_time = time.time()
print(" End time is ", end_time)

print("The total time required for ops is", end_time - start_time)
# Out:
# Start time is  1746759607.0096223
#  End time is  1746759613.7083118
# The total time required for ops is 6.6986894607543945

# %%
# %%time

for i in range(100000000):
  pass
# Out:
# CPU times: user 5.65 s, sys: 5.55 ms, total: 5.66 s
# Wall time: 5.77 s

# %% [markdown]
# ### Datetime

# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 5, 12, 14, 46, 31, 575541)

# %%
curr_time = datetime.datetime.now()
print(curr_time)
# Out:
# 2025-05-12 14:48:26.561364

# %%
curr_date = datetime.datetime.today()
print(curr_date)
# Out:
# 2025-05-12 14:48:30.855424

# %%
curr_date.date()
# Out:
# datetime.date(2025, 5, 12)

# %%
curr_date.time()
# Out:
# datetime.time(14, 48, 30, 855424)

# %%
curr_date.hour
# Out:
# 14

# %%
curr_date.month
# Out:
# 5

# %%
curr_date.year
# Out:
# 2025

# %%
datetime.datetime.now().hour
# Out:
# 14

# %%
datetime.datetime.now().month
# Out:
# 5

# %%
datetime.datetime.now().second
# Out:
# 24

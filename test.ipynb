# %%
"hi"
# Out:
# 'hi'

# %%
# define a dataframe 5 students a & marks student name, columns marks

# %%
# Out:
#   Cell In[4], line 1
#     np.random.randint(50, 100) for i in range(5)
#                                ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

data = {
    "name": ["student1", "student2", "student3", "student4", "student5"],
    "marks": [np.random.randint(50, 100) for i in range(5)],
    "age": [np.random.randint(15, 20) for i in range(5)]
}

# %%
[np.random.randint(18, 25) for i in range(5)]
# Out:
# [22, 21, 20, 21, 23]

# %%
[np.random.randint(50, 100) for i in range(5)]
# Out:
# [61, 92, 73, 98, 69]

# %%
data = {
    
    
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#        name  marks  age
# 0  student1     82   16
# 1  student2     63   15
# 2  student3     89   16
# 3  student4     61   15
# 4  student5     78   18

# %%
bins = [18, 20, 22, 25]
labels = ["18-20", "20-22", "22-25"]

df["age_group"] = pd.cut(df["age"], bins=bins, labels=labels, right=True)
print(df)
# Out:
#        name  marks  age age_group
# 0  student1     82   16       NaN
# 1  student2     63   15       NaN
# 2  student3     89   16       NaN
# 3  student4     61   15       NaN
# 4  student5     78   18       NaN

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split

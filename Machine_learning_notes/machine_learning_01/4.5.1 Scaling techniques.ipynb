# %% [markdown]
# # Sacling techniques

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')
df1 = df.copy()
df2 = df.copy()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(subset=['Fare'],axis=0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.5+ KB

# %% [markdown]
# ## Normalisation

# %% [raw]
# Range >> 0-1

# %% [raw]
# X_norm = (X_actual - Xmin) / (Xmax - Xmin)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
age = 25

age_min = df.Age.min()
age_max = df.Age.max()

print(age_max,age_min)

# %%
(25-0.42)/(80-0.42)

# %% [markdown]
# ### min-max scalar

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
normal_scalar= MinMaxScaler()
scaled_fair = normal_scalar.fit_transform(df[['Fare']])
print(scaled_fair)
df['Fare'] = pd.DataFrame(scaled_fair,columns={'Fare'})
df
# Out:
# [[0.01415106]
#  [0.13913574]
#  [0.01546857]
#  [0.1036443 ]
#  [0.01571255]
#  [0.0165095 ]
#  [0.10122886]
#  [0.04113566]
#  [0.02173075]
#  [0.05869429]
#  [0.03259623]
#  [0.05182215]
#  [0.01571255]
#  [0.06104473]
#  [0.01533038]
#  [0.03122992]
#  [0.05684821]
#  [0.02537431]
#  [0.03513366]
#  [0.01410226]
#  [0.05074862]
#  [0.02537431]
#  [0.01567195]
#  [0.06929139]
#  [0.04113566]
#  [0.06126432]
#  [0.01410226]
#  [0.51334181]
#  [0.01537917]
#  [0.01541158]
#  [0.0541074 ]
#  [0.28598956]
#  [0.01512699]
#  [0.02049464]
#  [0.16038672]
#  [0.10149724]
#  [0.01411046]
#  [0.01571255]
#  [0.03513366]
#  [0.02194234]
#  [0.01849397]
#  [0.04098927]
#  [0.01541158]
#  [0.08115719]
#  [0.01537917]
#  [0.01571255]
#  [0.03025399]
#  [0.01512699]
#  [0.04231498]
#  [0.03474329]
#  [0.07746484]
#  [0.01522459]
#  [0.14976542]
#  [0.05074862]
#  [0.12097534]
#  [0.06929139]
#  [0.02049464]
#  [0.01411046]
#  [0.05416439]
#  [0.0915427 ]
#  [0.01411046]
#  [0.1561496 ]
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.5+ KB

# %%
df['Fare'].unique()
# Out:
# array([0.01415106, 0.13913574, 0.01546857, 0.1036443 , 0.01571255,
#        0.0165095 , 0.10122886, 0.04113566, 0.02173075, 0.05869429,
#        0.03259623, 0.05182215, 0.06104473, 0.01533038, 0.03122992,
#        0.05684821, 0.02537431, 0.03513366, 0.01410226, 0.05074862,
#        0.01567195, 0.06929139, 0.06126432, 0.51334181, 0.01537917,
#        0.01541158, 0.0541074 , 0.28598956, 0.01512699, 0.02049464,
#        0.16038672, 0.10149724, 0.01411046, 0.02194234, 0.01849397,
#        0.04098927, 0.08115719, 0.03025399, 0.04231498, 0.03474329,
#        0.07746484, 0.01522459, 0.14976542, 0.12097534, 0.05416439,
#        0.0915427 , 0.1561496 , 0.16293235, 0.05445717, 0.02975782,
#        0.01592394, 0.01690807, 0.14346245, 0.02821272, 0.11027246,
#        0.01493181, 0.05660423, 0.02434958, 0.01756683, 0.01854277,
#        0.01520019, 0.09193308, 0.03093714, 0.06709553, 0.11940565,
#        0.04015973, 0.06764049, 0.12366717, 0.04489301, 0.15085515,
# ...

# %% [markdown]
# ## Standard scalar

# %% [raw]
# x_stad = (Xactual - X_mean)/X_mean_std
#
# >> It is also used to scale down based on standard  normal distribution wherein, mean will be 0 & std is 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from sklearn.preprocessing import StandardScaler
std_scalar = StandardScaler()
scaled_values = std_scalar.fit_transform(df1[['Fare']])
df1['Fare'] = pd.DataFrame(scaled_values)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1['Fare'].describe()
# Out:
# count    8.910000e+02
# mean    -4.373606e-17
# std      1.000562e+00
# min     -6.484217e-01
# 25%     -4.891482e-01
# 50%     -3.573909e-01
# 75%     -2.424635e-02
# max      9.667167e+00
# Name: Fare, dtype: float64

# %%
df1.Fare.min(),df1.Fare.max()
# Out:
# (-0.6484216535389205, 9.667166525013505)

# %%
import seaborn as sns
sns.boxplot(df['Fare'])
# Out:
# C:\Users\Pratik\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fare'>

# %% [markdown]
# ## Robust scalar

# %% [raw]
# robust scalar >> instead of using mean it used median
#
# >> it is used to scale down based on standard noraml distribution wherein, median will be 0 & std is 1.
#
# X_rob = (X_actual - X_median)/X_median_std

# %%
from sklearn.preprocessing import RobustScaler

Rob_scaler = RobustScaler()
rob_scaled_values = Rob_scaler.fit_transform(df2[['Fare']])
df2['Fare']=pd.DataFrame(rob_scaled_values)
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2['Fare'].describe()
# Out:
# count    891.000000
# mean       0.768745
# std        2.152200
# min       -0.626005
# 25%       -0.283409
# 50%        0.000000
# 75%        0.716591
# max       21.562738
# Name: Fare, dtype: float64

# %% [markdown]
# # Skew correction

# %% [markdown]
# ## log transform

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(subset=['Age'],inplace=True)

# %%
sns.kdeplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
df['Age']=np.log(df['Age'])
df['Age']
# Out:
# 0      3.091042
# 1      3.637586
# 2      3.258097
# 3      3.555348
# 4      3.555348
#          ...
# 885    3.663562
# 886    3.295837
# 887    2.944439
# 889    3.258097
# 890    3.465736
# Name: Age, Length: 714, dtype: float64

# %%
sns.kdeplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## square root transform

# %%
df = pd.read_csv('titanic.csv')
df['Age']= np.sqrt(df['Age'])
sns.kdeplot(df['Age'],fill=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## cube root trandform

# %%
df = pd.read_csv('titanic.csv')
df['Age']= np.cbrt(df['Age'])
sns.kdeplot(df['Age'],fill=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
0.3**2
# Out:
# 0.09

# %%
2**2
# Out:
# 4

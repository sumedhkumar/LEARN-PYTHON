# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.Gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.Gender.value_counts()
# Out:
# Gender
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.loc[(df.Gender == 'male')&(df['Survived']==1)]
# Out:
#      PassengerId  Survived  Pclass                             Name Gender  \
# 12            13         1       3   Saundercock, Mr. William Henry   male
# 16            17         1       3             Rice, Master. Eugene   male
# 17            18         1       2     Williams, Mr. Charles Eugene   male
# 21            22         1       2            Beesley, Mr. Lawrence   male
# 23            24         1       1     Sloper, Mr. William Thompson   male
# ..           ...       ...     ...                              ...    ...
# 838          839         1       3                  Chip, Mr. Chang   male
# 839          840         1       1             Marechal, Mr. Pierre   male
# 857          858         1       1           Daly, Mr. Peter Denis    male
# 869          870         1       3  Johnson, Master. Harold Theodor   male
# 889          890         1       1            Behr, Mr. Karl Howell   male
#
#       Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# ...

# %%
df.loc[(df.Gender == 'male')&(df['Survived']==0)].shape[0]
# Out:
# 465

# %%
df.loc[(df.Gender == 'female')&(df['Survived']==0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 38            39         0       3
# 40            41         0       3
# 41            42         0       2
# ..           ...       ...     ...
# 854          855         0       2
# 863          864         0       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Dtype function

# %%
df.Gender.dtype
# Out:
# dtype('O')

# %%
df.Survived.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Astype function

# %%
df.Survived = df.Survived.astype('float')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 886          887       0.0       2
# 887          888       1.0       1
# 888          889       0.0       3
# 889          890       1.0       1
# 890          891       0.0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dft = pd.DataFrame({'A': np.random.randint(10, 20, 5), 'B': [10, 20, 30, 40, 50]})
dft
# Out:
#     A   B
# 0  11  10
# 1  12  20
# 2  15  30
# 3  18  40
# 4  11  50

# %%
dft['C'] = 'GENAI'
dft
# Out:
#     A   B      C
# 0  11  10  GENAI
# 1  12  20  GENAI
# 2  15  30  GENAI
# 3  18  40  GENAI
# 4  11  50  GENAI

# %%
dft['D'] = dft['A'] + dft['B']
dft
# Out:
#     A   B      C   D
# 0  11  10  GENAI  21
# 1  12  20  GENAI  32
# 2  15  30  GENAI  45
# 3  18  40  GENAI  58
# 4  11  50  GENAI  61

# %%
dft['D'] = dft['D'].astype('str')
dft['D'].dtype
# Out:
# dtype('O')

# %%
dft['D'] = dft['D'] + '%'
dft
# Out:
#     A   B      C    D
# 0  11  10  GENAI  21%
# 1  12  20  GENAI  32%
# 2  15  30  GENAI  45%
# 3  18  40  GENAI  58%
# 4  11  50  GENAI  61%

# %% [markdown]
# ## Insert()

# %%
# syntax :
# df.insert(location_index, column_name, column_values)

# %%
dft
# Out:
#     A   B      C    D
# 0  11  10  GENAI  21%
# 1  12  20  GENAI  32%
# 2  15  30  GENAI  45%
# 3  18  40  GENAI  58%
# 4  11  50  GENAI  61%

# %%
dft.insert(1, 'X', [-11, -22, -33, -44, -55])
dft
# Out:
#     A   X   B      C    D
# 0  11 -11  10  GENAI  21%
# 1  12 -22  20  GENAI  32%
# 2  15 -33  30  GENAI  45%
# 3  18 -44  40  GENAI  58%
# 4  11 -55  50  GENAI  61%

# %%
dft.insert(5, 'Z', 10000)
dft
# Out:
#     A   X   B      C    D      Z
# 0  11 -11  10  GENAI  21%  10000
# 1  12 -22  20  GENAI  32%  10000
# 2  15 -33  30  GENAI  45%  10000
# 3  18 -44  40  GENAI  58%  10000
# 4  11 -55  50  GENAI  61%  10000

# %%
dft.insert(1,'V',11)
dft
# Out:
#     A   V   X   B      C    D      Z
# 0  11  11 -11  10  GENAI  21%  10000
# 1  12  11 -22  20  GENAI  32%  10000
# 2  15  11 -33  30  GENAI  45%  10000
# 3  18  11 -44  40  GENAI  58%  10000
# 4  11  11 -55  50  GENAI  61%  10000

# %% [markdown]
# ## Arranging Rows and Columns as per need

# %%
dft[['A', 'B', 'C', 'D', 'V', 'X', 'Z']]
# Out:
#     A   B      C    D   V   X      Z
# 0  11  10  GENAI  21%  11 -11  10000
# 1  12  20  GENAI  32%  11 -22  10000
# 2  15  30  GENAI  45%  11 -33  10000
# 3  18  40  GENAI  58%  11 -44  10000
# 4  11  50  GENAI  61%  11 -55  10000

# %%
df = dft.T
df
# Out:
#        0      1      2      3      4
# A     11     12     15     18     11
# V     11     11     11     11     11
# X    -11    -22    -33    -44    -55
# B     10     20     30     40     50
# C  GENAI  GENAI  GENAI  GENAI  GENAI
# D    21%    32%    45%    58%    61%
# Z  10000  10000  10000  10000  10000

# %%
df1 = df[[2, 0, 1, 3, 4]].T

# %%
df1
# Out:
#     A   V    X   B      C    D      Z
# 2  15  11  -33  30  GENAI  45%  10000
# 0  11  11  -11  10  GENAI  21%  10000
# 1  12  11  -22  20  GENAI  32%  10000
# 3  18  11  -44  40  GENAI  58%  10000
# 4  11  11  -55  50  GENAI  61%  10000

# %%
df1.insert(1,'P1',[7,7,8,8,9]) # We need same column length
df1
# Out:
#     A  P1  P   V    X   B      C    D      Z
# 2  15   7  7  11  -33  30  GENAI  45%  10000
# 0  11   7  7  11  -11  10  GENAI  21%  10000
# 1  12   8  8  11  -22  20  GENAI  32%  10000
# 3  18   8  8  11  -44  40  GENAI  58%  10000
# 4  11   9  9  11  -55  50  GENAI  61%  10000

# %%
df1.insert(18,'P2',[7,7,8,8,9]) # We need same column length
df1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-0be4c8a68aca> in <cell line: 0>()
# ----> 1 df1.insert(18,'P2',[7,7,8,8,9]) # We need same column length
#       2 df1
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    5170
#    5171         value, refs = self._sanitize_column(value)
# -> 5172         self._mgr.insert(loc, column, value, refs=refs)
#    5173
#    5174     def assign(self, **kwargs) -> DataFrame:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, refs)
#    1363                 category=FutureWarning,
#    1364             )
# -> 1365             new_axis = self.items.insert(loc, item)
#    1366
#    1367         if value.ndim == 2:
#
# ...

# %% [markdown]
# ## Re-Name

# %%
dfx = df.T
dfx
# Out:
#     A   V    X   B      C    D      Z
# 0  11  11  -11  10  GENAI  21%  10000
# 1  12  11  -22  20  GENAI  32%  10000
# 2  15  11  -33  30  GENAI  45%  10000
# 3  18  11  -44  40  GENAI  58%  10000
# 4  11  11  -55  50  GENAI  61%  10000

# %%
dfx.rename(columns={'A':'a'}, inplace=True)
dfx
# Out:
#     a   V    X   B      C    D      Z
# 0  11  11  -11  10  GENAI  21%  10000
# 1  12  11  -22  20  GENAI  32%  10000
# 2  15  11  -33  30  GENAI  45%  10000
# 3  18  11  -44  40  GENAI  58%  10000
# 4  11  11  -55  50  GENAI  61%  10000

# %%
dfx.rename({'V':'Virat'}, inplace=True, axis=1)
dfx
# Out:
#     a Virat    X   B      C    D      Z
# 0  11    11  -11  10  GENAI  21%  10000
# 1  12    11  -22  20  GENAI  32%  10000
# 2  15    11  -33  30  GENAI  45%  10000
# 3  18    11  -44  40  GENAI  58%  10000
# 4  11    11  -55  50  GENAI  61%  10000

# %%
dfx.rename({0:'Movie',1:'simran', 2:'raj', 3:'Heer', 4:'Ranjha'}, inplace=True, axis=0)
dfx
# Out:
#          a Virat    X   B      C    D      Z
# Movie   11    11  -11  10  GENAI  21%  10000
# simran  12    11  -22  20  GENAI  32%  10000
# raj     15    11  -33  30  GENAI  45%  10000
# Heer    18    11  -44  40  GENAI  58%  10000
# Ranjha  11    11  -55  50  GENAI  61%  10000

# %%
dfx.rename({"Movie":'₹'},inplace= True,axis=0)

# %%
dfx
# Out:
#          a Virat    X   B      C    D      Z
# ₹       11    11  -11  10  GENAI  21%  10000
# simran  12    11  -22  20  GENAI  32%  10000
# raj     15    11  -33  30  GENAI  45%  10000
# Heer    18    11  -44  40  GENAI  58%  10000
# Ranjha  11    11  -55  50  GENAI  61%  10000

# %%
dfx
# Out:
#          a Virat    X   B      C    D      Z
# ₹       11    11  -11  10  GENAI  21%  10000
# simran  12    11  -22  20  GENAI  32%  10000
# raj     15    11  -33  30  GENAI  45%  10000
# Heer    18    11  -44  40  GENAI  58%  10000
# Ranjha  11    11  -55  50  GENAI  61%  10000

# %%
df5 = dfx.rename({"₹":'₹1vn'},inplace=False,axis=0)
df5
# Out:
#          a Virat    X   B      C    D      Z
# ₹1vn    11    11  -11  10  GENAI  21%  10000
# simran  12    11  -22  20  GENAI  32%  10000
# raj     15    11  -33  30  GENAI  45%  10000
# Heer    18    11  -44  40  GENAI  58%  10000
# Ranjha  11    11  -55  50  GENAI  61%  10000
